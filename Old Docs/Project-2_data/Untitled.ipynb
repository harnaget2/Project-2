# %%
import pandas as pd

# %%
data = pd.read_excel('Traffic Data V 2.xlsx')

# %%
data.head()
# Out:
#      State  STATE  ST_CASE  Number of Vehicle Forms Submitted- ALL  \
# 0  Alabama      1    10186                                       1
# 1  Alabama      1    10189                                       2
# 2  Alabama      1    10207                                       2
# 3  Alabama      1    10293                                       1
# 4  Alabama      1    10326                                       1
#
#    Number of Motor Vehicles in Transport (MVIT)   \
# 0                                              1
# 1                                              2
# 2                                              2
# 3                                              1
# 4                                              1
#
#    Number of Parked/Working Vehicles   \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
# ...

# %%
graphdata = data[['State','Number of Vehicle Forms Submitted- ALL']]

# %%
graphdata = graphdata.groupby('State').sum()

# %%
graphdata.to_csv('flair.csv',sep=',')
